# %%
import os
import numpy as np
from osgeo import gdal
import tqdm
import rasterio
import pandas as pd
from matplotlib import pyplot
import pickle
import tqdm

# %%
table = pd.read_csv(os.path.dirname(os.getcwd())+'\\OUTPUTS\\INTERMEDIATE\\classified_state_temp.csv')
state_name = table['State'].unique()[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-532c0a53509a> in <module>
# ----> 1 table = pd.read_csv(os.path.dirname(os.getcwd())+'\\OUTPUTS\\INTERMEDIATE\\classified_state_temp.csv')
#       2 state_name = table['State'].unique()[0]
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
ds = rasterio.open(os.path.dirname(os.getcwd())+'\\OUTPUTS\\INTERMEDIATE\\'+state_name+'\\ID_NLCD_temp.tif')

# %%
ar =ds.read(1)

# %%
[print(i) for i in np.unique(ar) if str(i).endswith('000000')]
# Out:
# 100000000
# 110000000
# 120000000
# 130000000
# 140000000
# 150000000
# 160000000
# 200000000
# 300000000
# 400000000
# 500000000
# 600000000
# 700000000
# 800000000
# 900000000
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
ar_general_public = np.where(((ar == 100000000) | (ar == 110000000) | (ar == 120000000) | (ar == 130000000) | 
                             (ar == 140000000) | (ar == 150000000) | (ar == 160000000) | (ar == 200000000) | 
                             (ar == 300000000) | (ar == 400000000) | (ar == 500000000) | (ar == 600000000) | 
                             (ar == 700000000) | (ar == 800000000) | (ar == 900000000)), ar, 0)

ar = np.where((ar != 100000000) | (ar != 110000000) | (ar != 120000000) | (ar != 130000000) | 
              (ar != 140000000) | (ar != 150000000) | (ar != 160000000) | (ar != 200000000) | 
              (ar != 300000000) | (ar != 400000000) | (ar != 500000000) | (ar != 600000000) | 
              (ar != 700000000) | (ar != 800000000) | (ar != 900000000), ar, 0)

# %%
ar = ar[np.where(ar != 0)]

# %%
ar = ar[np.where(ar != -2147483647)]

# %%
df=pd.DataFrame(ar)

# %%
df.columns = ['Codes']

# %%
def decode(x):
    global idlc
    prclid = str(x)[-6:]
    lc_type = str(x).split('0')[0]
    if prclid not in idlc:
        idlc[prclid] = [lc_type]
    else:
        idlc[prclid].append(lc_type)

# %%
idlc={}
f = lambda x: decode(x)
[f(xi) for xi in ar]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
nums = [i for i in range(1,17)]
nums.remove(10)

# %%
df = pd.DataFrame({'PRCL_id':[],'Open Water':[], 'Developed, Open Space':[], 'Developed, Low Intensity':[],
'Developed, Medium Intensity':[], 'Developed, High Intensity':[], 
'Barren Land':[], 'Deciduous Forest':[], 'Evergreen Forest':[],
'Mixed Forest':[], 'Shrub/Scrub':[],  'Herbaceuous':[], 'Hay/Pasture':[],
'Cultivated Crops':[], 'Woody Wetlands':[], 'Emergent Herbaceuous Wetlands':[]})

# %%
def pop_df(key):
    rec=[int(key)]
    for n in nums:
        rec.append(idlc[key].count(str(n))/len(idlc[key]))
    df.loc[len(df)] = rec

# %%
f = lambda x: pop_df(x)
[f(ix) for ix in idlc]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
new_nums = list(np.unique(ar_general_public))[1:]

# %%
gp = ['General Public']
for n in new_nums:
    gp.append((np.count_nonzero(ar_general_public == n))/(np.count_nonzero(ar_general_public != 0)))

# %%
df['PRCL_id']=df['PRCL_id'].astype(int)

# %%
id_df = pd.read_csv(os.path.dirname(os.getcwd())+'\\OUTPUTS\\INTERMEDIATE\\'+state_name+'\\ID_Dictionary.csv')

# %%
id_df = id_df[['Value', 'PRCLDMPID']]

# %%
id_dict = {}
for i in range(len(id_df['Value'])):
    id_dict[id_df['Value'][i]] = id_df['PRCLDMPID'][i]

# %%
df['PRCLDMPID'] = df.PRCL_id.map(id_dict)

# %%
#table = pd.read_csv(os.path.dirname(os.getcwd())+'\\OUTPUTS\\INTERMEDIATE\\classified_state_temp.csv')
# Out:
# C:\Users\harri\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (4,14,17,21,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
joined = pd.merge(table, df)

# %%
joined.to_csv(os.path.dirname(os.getcwd())+'\\OUTPUTS\\INTERMEDIATE\\Full_Data_Table.csv')

# %%
print('Land Cover Analyzed')
